# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Opening a local csv file

# %%
df = pd.read_csv('/content/drive/MyDrive/ML/dataFrame/Csv/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %% [markdown]
# # Opening a csv file from an URL

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# # Sep Parameter
# ## dealing with files liks tsv and other
# here we have example of tsv tab seperated file
# and extracting only required colum from the file

# %%
df2 = pd.read_csv('/content/drive/MyDrive/ML/dataFrame/Csv/movie_titles_metadata.tsv',sep='\t',names=['sno','name','release_year','rating','votes','genres'])

# %%
df2.head()
# Out:
#   sno                        name release_year  rating     votes  \
# 0  m0  10 things i hate about you         1999     6.9   62847.0
# 1  m1  1492: conquest of paradise         1992     6.2   10421.0
# 2  m2                  15 minutes         2001     6.1   25854.0
# 3  m3       2001: a space odyssey         1968     8.4  163227.0
# 4  m4                     48 hrs.         1982     6.9   22289.0
#
#                                            genres
# 0                            ['comedy' 'romance']
# 1     ['adventure' 'biography' 'drama' 'history']
# 2           ['action' 'crime' 'drama' 'thriller']
# 3                ['adventure' 'mystery' 'sci-fi']
# 4  ['action' 'comedy' 'crime' 'drama' 'thriller']

# %%
df2.shape
# Out:
# (617, 6)

# %% [markdown]
# # Skiprows/nrows Parameter

# %% [markdown]
# **bold text** nrow when we need a limited row in df

# %%
df3 = pd.read_csv('/content/drive/MyDrive/ML/dataFrame/Csv/placement.csv', nrows=100)

# %%
df3.shape
# Out:
# (100, 4)

# %%
df = pd.read_csv('/content/drive/MyDrive/ML/dataFrame/Csv/placement.csv', nrows=100)
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %% [markdown]
# ### Skiping rows we can pass **function** also

# %%
df = pd.read_csv('/content/drive/MyDrive/ML/dataFrame/Csv/placement.csv', nrows=100, skiprows=[0, 2, 5])
df.head()
# Out:
#    0  6.8  123.0  1
# 0  2  5.3  121.0  0
# 1  3  7.4  132.0  1
# 2  5  7.1   48.0  1
# 3  6  5.7  143.0  0
# 4  7  5.0   63.0  0

# %%
df.shape
# Out:
# (97, 4)

# %% [markdown]
# # Loading a huge dataset in chunks

# %%
dfs = pd.read_csv('/content/drive/MyDrive/ML/dataFrame/Csv/placement.csv', chunksize=30)

df_list = []  # Initialize an empty list to hold the chunks

for chunk in dfs:
    print(chunk.shape)
    df_list.append(chunk)  # Append each chunk to the list

# Concatenate all chunks into a single DataFrame
df = pd.concat(df_list, ignore_index=True)

print(df.shape)  # Print the final DataFrame's shape
# Out:
# (30, 4)
# (30, 4)
# (30, 4)
# (10, 4)
# (100, 4)

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
dfs = pd.read_csv('/content/drive/MyDrive/ML/dataFrame/Csv/placement.csv', chunksize=30)
for chunk in dfs:
    print(chunk.shape)
# Out:
# (30, 4)
# (30, 4)
# (30, 4)
# (10, 4)
